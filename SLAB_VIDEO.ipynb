# %%
# if running this code in a Jupter notbeook or JupyterLab
# %matplotlib ipympl
import mpl_interactions.ipyplot as iplt
import matplotlib.pyplot as plt
from ipywidgets import IntSlider, Label

import numpy as np

c = 299792458.

psi_0 = 95
frac_pol = np.linspace(0.01, 0.5, 100)
RM_src = np.linspace (1, 101, 100)
RM_screen = np.linspace (-1100, 1100, 100)

#x axis
lower_freq_lim_Hz = 800.e6
upper_freq_lim_Hz = 1089.e6
channel_width_Hz = 1.e6
freq_array = np.arange(lower_freq_lim_Hz, upper_freq_lim_Hz, channel_width_Hz)
lambda_sqr_array = np.power(c/freq_array, 2.0)

#def add_noise_SNR 

def real_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src):
    return (frac_pol * np.exp(2j * (np.radians(psi_0) + (0.5 * RM_src + RM_screen) * lambda_sqr_array)) * ((np.sin(RM_src * lambda_sqr_array)) / (RM_src * lambda_sqr_array))).real 

def imag_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src):
    return (frac_pol * np.exp(2j * (np.radians(psi_0) + (0.5 * RM_src + RM_screen) * lambda_sqr_array)) * ((np.sin(RM_src * lambda_sqr_array)) / (RM_src * lambda_sqr_array))).imag 

def slab(lambda_sqr_array, frac_pol, RM_screen,RM_src):
    imaginary =  imag_slab(lambda_sqr_array, frac_pol, RM_screen,RM_src)
    real = real_slab(lambda_sqr_array, frac_pol, RM_screen,RM_src)
    return np.sqrt(real**2 + imaginary**2)

fig, ax = plt.subplots(figsize=[4,4])
fig.canvas.header_visible = False


controls = iplt.plot(lambda_sqr_array, real_slab, frac_pol=frac_pol, RM_screen=RM_screen, RM_src=RM_src, color = 'blue',label="Q", linewidth=3)
iplt.plot(lambda_sqr_array, imag_slab, controls=controls,color='red', label="U", linewidth=3)
iplt.plot(lambda_sqr_array, slab , controls=controls,color='black', label="P",linewidth=3)


iplt.xlabel('$\lambda^2$', fontsize=18)
iplt.ylabel('P($\lambda^2$)', fontsize=18)
plt.tight_layout()
plt.show()
# Out:
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_78693/10833720.py:45: SyntaxWarning: invalid escape sequence '\l'
#   iplt.xlabel('$\lambda^2$', fontsize=18)
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_78693/10833720.py:46: SyntaxWarning: invalid escape sequence '\l'
#   iplt.ylabel('P($\lambda^2$)', fontsize=18)
# VBox(children=(HBox(children=(IntSlider(value=0, description='frac_pol', max=99, readout=False), Label(value='…
# VBox()
# VBox()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 matplotlib.rcParams.update(matplotlib.rcParamsDefault)
#
# NameError: name 'matplotlib' is not defined

# %%
psi_0 = np.linspace(1,180,180)
frac_pol = np.linspace(0.01, 0.5, 100)
RM_src = 0.01
RM_screen = np.linspace (-1100, 1100, 100)

#x axis
lower_freq_lim_Hz = 800.e6
upper_freq_lim_Hz = 1089.e6
channel_width_Hz = 1.e6
freq_array = np.arange(lower_freq_lim_Hz, upper_freq_lim_Hz, channel_width_Hz)
lambda_sqr_array = np.power(c/freq_array, 2.0)

#def add_noise_SNR 

def real_simple(lambda_sqr_array, frac_pol, RM_screen, psi_0):
    return (frac_pol * np.exp(2j * (np.radians(psi_0) + (0.5 * RM_src + RM_screen) * lambda_sqr_array)) * ((np.sin(RM_src * lambda_sqr_array)) / (RM_src * lambda_sqr_array))).real 

def imag_simple(lambda_sqr_array, frac_pol, RM_screen, psi_0):
    return (frac_pol * np.exp(2j * (np.radians(psi_0) + (0.5 * RM_src + RM_screen) * lambda_sqr_array)) * ((np.sin(RM_src * lambda_sqr_array)) / (RM_src * lambda_sqr_array))).imag 

def simple(lambda_sqr_array, frac_pol, RM_screen, psi_0):
    imaginary =  imag_simple(lambda_sqr_array, frac_pol, RM_screen, psi_0)
    real = real_simple(lambda_sqr_array, frac_pol, RM_screen, psi_0)
    return np.sqrt(real**2 + imaginary**2)

fig, ax = plt.subplots(figsize=[4,4])
fig.canvas.header_visible = False

controls = iplt.plot(lambda_sqr_array, real_simple,frac_pol=frac_pol, RM_screen=RM_screen,psi_0=psi_0, color = 'blue',label="Q", linewidth=3)
iplt.plot(lambda_sqr_array, imag_simple, controls=controls,color='red', label="U", linewidth=3)
iplt.plot(lambda_sqr_array,simple , controls=controls,color='black', label="P",linewidth=3)

iplt.xlabel('$\lambda^2$', color='black', fontsize=12)
iplt.ylabel('P($\lambda^2$)', color='black', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# <>:33: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_74259/1364209358.py:33: SyntaxWarning: invalid escape sequence '\l'
#   iplt.xlabel('$\lambda^2$', color='black', fontsize=12)
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_74259/1364209358.py:34: SyntaxWarning: invalid escape sequence '\l'
#   iplt.ylabel('P($\lambda^2$)', color='black', fontsize=12)
# VBox(children=(HBox(children=(IntSlider(value=0, description='frac_pol', max=99, readout=False), Label(value='…
# VBox()
# VBox()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
psi_01 = np.linspace(1,180,180)
frac_pol1 = np.linspace(0.01, 0.5, 100)
RM_screen1 = np.linspace (-1100, 1100, 100)

psi_02 = np.linspace(1,180,180)
frac_pol2 = np.linspace(0.01, 0.5, 100)
RM_screen2 = np.linspace (-1100, 1100, 100)

#x axis
lower_freq_lim_Hz = 800.e6
upper_freq_lim_Hz = 1089.e6
channel_width_Hz = 1.e6
freq_array = np.arange(lower_freq_lim_Hz, upper_freq_lim_Hz, channel_width_Hz)
lambda_sqr_array = np.power(c/freq_array, 2.0)

#def add_noise_SNR 

def real_2compo(lambda_sqr_array, frac_pol1, RM_screen1, psi_01, frac_pol2, RM_screen2, psi_02):
    return (frac_pol1 * np.exp(2j * (np.radians(psi_01) + (0.5 * RM_screen1 * lambda_sqr_array))) + (frac_pol2 * np.exp(2j * (np.radians(psi_02) + (0.5 * RM_screen2 * lambda_sqr_array))))).real

def imag_2compo(lambda_sqr_array, frac_pol1, RM_screen1, psi_01, frac_pol2, RM_screen2, psi_02):
    return (frac_pol1 * np.exp(2j * (np.radians(psi_01) + (0.5 * RM_screen1 * lambda_sqr_array))) + (frac_pol2 * np.exp(2j * (np.radians(psi_02) + (0.5 * RM_screen2 * lambda_sqr_array))))).imag 

def twocomp(lambda_sqr_array, frac_pol1, RM_screen1, psi_01, frac_pol2, RM_screen2, psi_02):
    imaginary =  imag_2compo(lambda_sqr_array, frac_pol1, RM_screen1, psi_01, frac_pol2, RM_screen2, psi_02)
    real = real_2compo(lambda_sqr_array, frac_pol1, RM_screen1, psi_01, frac_pol2, RM_screen2, psi_02)
    return np.sqrt(real**2 + imaginary**2)

fig, ax = plt.subplots(figsize=[4,4])
fig.canvas.header_visible = False


controls = iplt.plot(lambda_sqr_array, real_2compo, frac_pol1=frac_pol1, RM_screen1=RM_screen1, psi_01=psi_01, frac_pol2=frac_pol2, RM_screen2=RM_screen2,psi_02=psi_02, color = 'blue',label="Q", linewidth=3)
iplt.plot(lambda_sqr_array, imag_2compo, controls=controls,color='red', label="U", linewidth=3)
iplt.plot(lambda_sqr_array, twocomp , controls=controls,color='black', label="P",linewidth=3)

iplt.xlabel('$\lambda^2$', color='black', fontsize=12)
iplt.ylabel('P($\lambda^2$)', color='black', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\l'
# <>:38: SyntaxWarning: invalid escape sequence '\l'
# <>:37: SyntaxWarning: invalid escape sequence '\l'
# <>:38: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_78693/1223455063.py:37: SyntaxWarning: invalid escape sequence '\l'
#   iplt.xlabel('$\lambda^2$', color='black', fontsize=12)
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_78693/1223455063.py:38: SyntaxWarning: invalid escape sequence '\l'
#   iplt.ylabel('P($\lambda^2$)', color='black', fontsize=12)
# VBox(children=(HBox(children=(IntSlider(value=0, description='frac_pol1', max=99, readout=False), Label(value=…
# VBox()
# VBox()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
psi_0 = 95
frac_pol = np.linspace(0.01, 0.5, 100)
RM_src = np.linspace (1, 101, 100)
sigma_RM = np.linspace (1, 101, 100)
RM_screen = np.linspace (-1100, 1100, 100)

#x axis
lower_freq_lim_Hz = 800.e6
upper_freq_lim_Hz = 1089.e6
channel_width_Hz = 1.e6

#freq_array_band_2 = np.arange(lower_freq_lim_Hz_band2, upper_freq_lim_Hz_band2, channel_width_Hz)
freq_array = np.arange(lower_freq_lim_Hz, upper_freq_lim_Hz, channel_width_Hz)
lambda_sqr_array = np.power(c/freq_array, 2.0)
#combined_frq_array = np.concatenate((freq_array, freq_array_band_2), axis=0)
#lambda_sqr_array = np.power(c/combined_frq_array, 2.0)

#def add_noise_SNR 

def real_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM):
    para_S = (2. * lambda_sqr_array**2 * sigma_RM**2 - 2j * lambda_sqr_array * RM_src)
    return (frac_pol * np.exp( 2j * (np.radians(psi_0) + RM_screen * lambda_sqr_array)) * (1 - np.exp(-1.*para_S)) / para_S).real
    
def imag_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM):
    para_S = (2. * lambda_sqr_array**2 * sigma_RM**2 - 2j * lambda_sqr_array * RM_src)
    return (frac_pol * np.exp( 2j * (np.radians(psi_0) + RM_screen * lambda_sqr_array)) * (1 - np.exp(-1.*para_S)) / para_S).imag
    
def mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM):
    imaginary =  imag_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM)
    real = real_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM)
    return np.sqrt(real**2 + imaginary**2)

fig, ax = plt.subplots(figsize=[4,4])
fig.canvas.header_visible = False
fig.patch.set_facecolor("black")
ax.set_facecolor("black")
ax.spines["bottom"].set_color("white")  # X-axis line
ax.spines["left"].set_color("white") 

controls = iplt.plot(lambda_sqr_array, real_mixed_slab, frac_pol=frac_pol, RM_screen=RM_screen, RM_src=RM_src, sigma_RM=sigma_RM, color = 'blue',label="Q", linewidth=3)
iplt.plot(lambda_sqr_array, imag_mixed_slab, controls=controls,color='red', label="U", linewidth=3)
iplt.plot(lambda_sqr_array,mixed_slab , controls=controls,color='white', label="P",linewidth=3)
_ = plt.legend(loc='upper right')

iplt.xlabel('$\lambda^2$', fontsize=18)
iplt.ylabel('P($\lambda^2$)', fontsize=18)
iplt.title('Mixed Slab')
plt.tight_layout()
plt.show()
# Out:
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_81966/2130996283.py:45: SyntaxWarning: invalid escape sequence '\l'
#   iplt.xlabel('$\lambda^2$', fontsize=18)
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_81966/2130996283.py:46: SyntaxWarning: invalid escape sequence '\l'
#   iplt.ylabel('P($\lambda^2$)', fontsize=18)
# VBox(children=(HBox(children=(IntSlider(value=0, description='frac_pol', max=99, readout=False), Label(value='…
# VBox()
# VBox()
# VBox()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
psi_0 = 95
frac_pol = np.linspace(0.01, 0.5, 100)
RM_src = np.linspace (1, 101, 100)
sigma_RM = np.linspace (1, 101, 100)
RM_screen = np.linspace (-1100, 1100, 100)

#x axis
lower_freq_lim_Hz_band2 = 1295.5 *10**6
upper_freq_lim_Hz_band2 = 1439.5 *10**6
channel_width_Hz = 1.e6
freq_array = np.arange(lower_freq_lim_Hz, upper_freq_lim_Hz, channel_width_Hz)
freq_array_band_2 = np.arange(lower_freq_lim_Hz_band2, upper_freq_lim_Hz_band2, channel_width_Hz)

combined_frq_array = np.concatenate((freq_array, freq_array_band_2), axis=0)

lambda_sqr_array = np.power(c/combined_frq_array, 2.0)

#def add_noise_SNR 

def real_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM):
    para_S = (2. * lambda_sqr_array**2 * sigma_RM**2 - 2j * lambda_sqr_array * RM_src)
    return (frac_pol * np.exp( 2j * (np.radians(psi_0) + RM_screen * lambda_sqr_array)) * (1 - np.exp(-1.*para_S)) / para_S).real
    
def imag_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM):
    para_S = (2. * lambda_sqr_array**2 * sigma_RM**2 - 2j * lambda_sqr_array * RM_src)
    return (frac_pol * np.exp( 2j * (np.radians(psi_0) + RM_screen * lambda_sqr_array)) * (1 - np.exp(-1.*para_S)) / para_S).imag
    
def mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM):
    imaginary =  imag_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM)
    real = real_mixed_slab(lambda_sqr_array, frac_pol, RM_screen, RM_src, sigma_RM)
    return np.sqrt(real**2 + imaginary**2)

fig, ax = plt.subplots(figsize=[4,4])
fig.canvas.header_visible = False

controls = iplt.plot(lambda_sqr_array, real_mixed_slab, frac_pol=frac_pol, RM_screen=RM_screen, RM_src=RM_src, sigma_RM=sigma_RM, color = 'blue',label="Q", linewidth=3)
iplt.plot(lambda_sqr_array, imag_mixed_slab, controls=controls,color='red', label="U", linewidth=3)
iplt.plot(lambda_sqr_array,mixed_slab , controls=controls,color='black', label="P",linewidth=3)
_ = plt.legend(loc='upper right')

iplt.xlabel('$\lambda^2$', fontsize=18)
iplt.ylabel('P($\lambda^2$)', fontsize=18)
iplt.title('Mixed Slab')
plt.tight_layout()
plt.show()
# Out:
# <>:41: SyntaxWarning: invalid escape sequence '\l'
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# <>:41: SyntaxWarning: invalid escape sequence '\l'
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_45228/3153219918.py:41: SyntaxWarning: invalid escape sequence '\l'
#   iplt.xlabel('$\lambda^2$', fontsize=18)
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_45228/3153219918.py:42: SyntaxWarning: invalid escape sequence '\l'
#   iplt.ylabel('P($\lambda^2$)', fontsize=18)
# VBox(children=(HBox(children=(IntSlider(value=0, description='frac_pol', max=99, readout=False), Label(value='…
# VBox()
# VBox()
# VBox()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
psi_0 = 95
frac_pol = np.linspace(0.01, 0.5, 100)
RM_src = np.linspace (1, 101, 100)
sigma_RM = np.linspace (1, 101, 100)
RM_screen = np.linspace (-1100, 1100, 100)

#x axis
lower_freq_lim_Hz_band2 = 1295.5 *10**6
upper_freq_lim_Hz_band2 = 1439.5 *10**6
channel_width_Hz = 1.e6
freq_array = np.arange(lower_freq_lim_Hz, upper_freq_lim_Hz, channel_width_Hz)
freq_array_band_2 = np.arange(lower_freq_lim_Hz_band2, upper_freq_lim_Hz_band2, channel_width_Hz)

combined_frq_array = np.concatenate((freq_array, freq_array_band_2), axis=0)

lambda_sqr_array = np.power(c/combined_frq_array, 2.0)

#def add_noise_SNR 

def real_random_screen(lambda_sqr_array, frac_pol, RM_screen, sigma_RM):
   
    return (frac_pol * np.exp( 2j * (np.radians(psi_0) + RM_screen * lambda_sqr_array)) * np.exp(-2 * lambda_sqr_array**(2) * sigma_RM**2.)).real
    
def imag_random_screen(lambda_sqr_array, frac_pol, RM_screen, sigma_RM):
    return (frac_pol * np.exp( 2j * (np.radians(psi_0) + RM_screen * lambda_sqr_array)) * np.exp(-2 * lambda_sqr_array**(2) * sigma_RM**2.)).imag
    
def random_screen(lambda_sqr_array, frac_pol, RM_screen, sigma_RM):
    imaginary =  imag_random_screen(lambda_sqr_array, frac_pol, RM_screen, sigma_RM)
    real = real_random_screen(lambda_sqr_array, frac_pol, RM_screen, sigma_RM)
    return np.sqrt(real**2 + imaginary**2)

fig, ax = plt.subplots(figsize=[4,4])
fig.canvas.header_visible = False

controls = iplt.plot(lambda_sqr_array, real_random_screen, frac_pol=frac_pol, RM_screen=RM_screen, sigma_RM=sigma_RM, color = 'blue',label="Q", linewidth=3)
iplt.plot(lambda_sqr_array, imag_random_screen, controls=controls,color='red', label="U", linewidth=3)
iplt.plot(lambda_sqr_array,random_screen , controls=controls,color='black', label="P",linewidth=3)
_ = plt.legend(loc='upper right')

iplt.xlabel('$\lambda^2$', fontsize=18)
iplt.ylabel('P($\lambda^2$)', fontsize=18)
iplt.title('Random FG Screen')
plt.tight_layout()
plt.show()
# Out:
# <>:40: SyntaxWarning: invalid escape sequence '\l'
# <>:41: SyntaxWarning: invalid escape sequence '\l'
# <>:40: SyntaxWarning: invalid escape sequence '\l'
# <>:41: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_37072/3056041453.py:40: SyntaxWarning: invalid escape sequence '\l'
#   iplt.xlabel('$\lambda^2$', fontsize=18)
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_37072/3056041453.py:41: SyntaxWarning: invalid escape sequence '\l'
#   iplt.ylabel('P($\lambda^2$)', fontsize=18)
# VBox(children=(HBox(children=(IntSlider(value=0, description='frac_pol', max=99, readout=False), Label(value='…
# VBox()
# VBox()
# VBox()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# # Make the MS + Random FG Screen

# %%
psi_0 = 40
frac_pol = np.linspace(0.01, 0.5, 100)
RM_src = np.linspace (1, 101, 100)
sigma_RM = np.linspace (1, 101, 100)
sigma_RM_FG = np.linspace (1, 101, 100)
RM_screen = np.linspace (-1100, 1100, 100)
#RM_screen_sing = 1000
#x axis
lower_freq_lim_Hz_band2 = 1295.5 *10**6
upper_freq_lim_Hz_band2 = 1439.5 *10**6
channel_width_Hz = 1.e6
freq_array = np.arange(lower_freq_lim_Hz, upper_freq_lim_Hz, channel_width_Hz)
freq_array_band_2 = np.arange(lower_freq_lim_Hz_band2, upper_freq_lim_Hz_band2, channel_width_Hz)

combined_frq_array = np.concatenate((freq_array, freq_array_band_2), axis=0)

lambda_sqr_array = np.power(c/combined_frq_array, 2.0)

#def add_noise_SNR 

def real_MS_random_screen(lambda_sqr_array, frac_pol, sigma_RM, sigma_RM_FG, RM_src, RM_screen):
    
    para_S = (2. * lambda_sqr_array**2 * sigma_RM**2 - 2j * lambda_sqr_array * RM_src)
    return (frac_pol * np.exp( 2j * (np.radians(psi_0) +  RM_screen * lambda_sqr_array)) * ((1 - np.exp(-1.*para_S)) / para_S) * np.exp(-2.0 * sigma_RM_FG**2.0 * lambda_sqr_array**2.0)).real
       
def imag_MS_random_screen(lambda_sqr_array, frac_pol, sigma_RM, sigma_RM_FG, RM_src, RM_screen):
    
    para_S = (2. * lambda_sqr_array**2 * sigma_RM**2 - 2j * lambda_sqr_array * RM_src)
    return  (frac_pol * np.exp( 2j * (np.radians(psi_0) +  RM_screen * lambda_sqr_array)) * ((1 - np.exp(-1.*para_S)) / para_S) * np.exp(-2.0 * sigma_RM_FG**2.0 * lambda_sqr_array**2.0)).imag
    
def Ms_random_screen(lambda_sqr_array, frac_pol, sigma_RM, sigma_RM_FG, RM_src, RM_screen):
    
    imaginary =  imag_MS_random_screen(lambda_sqr_array, frac_pol, sigma_RM, sigma_RM_FG, RM_src, RM_screen)
    real = real_MS_random_screen(lambda_sqr_array, frac_pol, sigma_RM, sigma_RM_FG, RM_src, RM_screen)
    return np.sqrt(real**2 + imaginary**2)

fig, ax = plt.subplots(figsize=[4,4])
fig.canvas.header_visible = False

controls = iplt.plot(lambda_sqr_array, real_MS_random_screen, frac_pol=frac_pol, sigma_RM=sigma_RM, sigma_RM_FG=sigma_RM_FG, RM_src=RM_src,RM_screen=RM_screen, color = 'blue',label="Q", linewidth=3)
iplt.plot(lambda_sqr_array, imag_MS_random_screen, controls=controls,color='red', label="U", linewidth=3)
iplt.plot(lambda_sqr_array,Ms_random_screen , controls=controls,color='black', label="P",linewidth=3)
_ = plt.legend(loc='upper right')

iplt.xlabel('$\lambda^2$', fontsize=18)
iplt.ylabel('P($\lambda^2$)', fontsize=18)
iplt.title('MS with Random FG Screen')
plt.tight_layout()
plt.show()
# Out:
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_45228/2870317701.py:45: SyntaxWarning: invalid escape sequence '\l'
#   iplt.xlabel('$\lambda^2$', fontsize=18)
# /var/folders/89/zgv9nv5563n89pzs55bv6mzm0000gq/T/ipykernel_45228/2870317701.py:46: SyntaxWarning: invalid escape sequence '\l'
#   iplt.ylabel('P($\lambda^2$)', fontsize=18)
# VBox(children=(HBox(children=(IntSlider(value=0, description='frac_pol', max=99, readout=False), Label(value='…
# VBox()
# VBox()
# VBox()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
from astropy.io import fits
import numpy as np
import pandas as pd

plt.rcParams.update({'font.size': 12})
plt.rc('font', family='serif')
figsize = (10, 12)
fig1, axs = plt.subplots(10, 4, figsize=figsize, constrained_layout=True)

for i in range(10):
    
    TC_FDF_file = '/Users/loberhel/Desktop/Project_2_Data/2Component_fake_100_video/{}_FDFdirty.dat'.format(i)

    data_FDF_2C = pd.read_csv(TC_FDF_file, sep=' ', header=None)

    FDF_BS = data_FDF_2C[1] ** 2 + data_FDF_2C[2] ** 2
    axs[i][1].plot(data_FDF_2C[0], FDF_BS, 'k')
    axs[i][1].set_xlim(0,400)
    axs[0][1].set_ylim(0,1.1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
import numpy as np

# Update plot settings
plt.rcParams.update({'font.size': 12})
plt.rc('font', family='serif')

SNRarr = np.linspace(3.0, 18.0, 40)


# Set up the figure
fig, ax = plt.subplots(figsize=(8, 6))

# Initialize the plot elements (empty lines)
line, = ax.plot([], [], 'k')
ax.set_xlim(-1000, 1000)
ax.set_ylim(0, 0.2)
ax.set_xlabel("Faraday Depth")
ax.set_ylabel("P")
title = ax.set_title("")

# Data paths and initialization
data_files = [
    f"/Users/loberhel/Desktop/Project_2_Data/2Component_fake_100_video/{i}_FDFdirty.dat"
    for i in range(40)]

# Animation function
def update(frame):
    # Read data for the current frame
    data_FDF_2C = pd.read_csv(data_files[frame], sep=' ', header=None)
    x = data_FDF_2C[0]
    FDF_BS = data_FDF_2C[1] ** 2 + data_FDF_2C[2] ** 2

    # Update the plot
    line.set_data(x, FDF_BS)
    title.set_text(f"S/N {np.round(SNRarr[frame-1])}")
  
    return line, title

# Create the animation
ani = FuncAnimation(fig, update, frames=len(data_files), blit=True)

# Save the animation as an MP4 video
ani.save('output_video.mov', writer='pillow', fps=0.01)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/PIL/Image.py:2436, in Image.save(self, fp, format, **params)
#    2435 try:
# -> 2436     format = EXTENSION[ext]
#    2437 except KeyError as e:
#
# KeyError: '.mov'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 46
#      43 ani = FuncAnimation(fig, update, frames=len(data_files), blit=True)
#      45 # Save the animation as an MP4 video
# ---> 46 ani.save('output_video.mov', writer='pillow', fps=0.01)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/animation.py:1085, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1081 savefig_kwargs['transparent'] = False   # just to be safe!
#    1082 # canvas._is_saving = True makes the draw_event animation-starting
#    1083 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1084 # widget (both are likewise done in savefig()).
# -> 1085 with mpl.rc_context({'savefig.bbox': None}), \
#    1086      writer.saving(self._fig, filename, dpi), \
#    1087      cbook._setattr_cm(self._fig.canvas,
#    1088                        _is_saving=True, manager=None):
#    1089     for anim in all_anim:
#    1090         anim._init_draw()  # Clear the initial frame
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/animation.py:235, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     233     yield self
#     234 finally:
# --> 235     self.finish()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/animation.py:501, in PillowWriter.finish(self)
#     500 def finish(self):
# --> 501     self._frames[0].save(
#     502         self.outfile, save_all=True, append_images=self._frames[1:],
#     503         duration=int(1000 / self.fps), loop=0)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/PIL/Image.py:2439, in Image.save(self, fp, format, **params)
#    2437     except KeyError as e:
#    2438         msg = f"unknown file extension: {ext}"
# -> 2439         raise ValueError(msg) from e
#    2441 if format.upper() not in SAVE:
#    2442     init()
#
# ValueError: unknown file extension: .mov
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
import numpy as np

# Update plot settings
plt.rcParams.update({'font.size': 12})
plt.rc('font', family='serif')

SNRarr = np.linspace(3.0, 18.0, 40)


# Set up the figure
fig, ax = plt.subplots(figsize=(8, 6))

# Initialize the plot elements (empty lines)
line, = ax.plot([], [], 'k')
ax.set_xlim(-1000, 1000)
ax.set_ylim(0, 0.002)
ax.set_xlabel("Faraday Depth")
ax.set_ylabel("P")
title = ax.set_title("")

# Data paths and initialization
data_files = [
    f"/Users/loberhel/Desktop/Project_2_Data/burnslab_fake_100/{i}_FDFdirty.dat"
    for i in range(40)]

# Animation function
def update(frame):
    # Read data for the current frame
    data_FDF_2C = pd.read_csv(data_files[frame], sep=' ', header=None)
    x = data_FDF_2C[0]
    FDF_BS = data_FDF_2C[1] ** 2 + data_FDF_2C[2] ** 2

    # Update the plot
    line.set_data(x, FDF_BS)
    title.set_text(f"S/N {np.round(SNRarr[frame-1])}")
  
    return line, title

# Create the animation
ani = FuncAnimation(fig, update, frames=len(data_files), blit=True)

# Save the animation as an MP4 video
ani.save('output_video_BS.gif', writer='pillow', fps=0.01)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
